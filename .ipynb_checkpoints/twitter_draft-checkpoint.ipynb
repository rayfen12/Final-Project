# %%
# Import dependencies 
import numpy as np
from twitter import *
import pandas as pd 
import datetime

# %%
#The tokens and consumers keys are my API authentication to use the Twitter API.  I'm using the twitter library as a python
#wrapper to call twitter request through python.
token = '1212463191910842368-l00ryMICeXQXXawl8w2zazEoFS7xDf'
token_secret = 'hbzjFRq1r2ygkydPXfrwrhm5zTa54F3mYEm2wi7Q09DgA'
consumer_key = 'g8V7jnF3dqMfg4LRhtobYB4Pl'
consumer_secret = 'Y0SHSL0H9X9gCtuy07mJ3cp144DS2JhwX4Uvgda2ph8NvIUswJ'

t = Twitter(
        auth=OAuth(token, token_secret, consumer_key, consumer_secret))

# %%
type(t)
# Out:
# twitter.api.Twitter

# %%
# The function below gets a person's timeline
# Note: Count can't be greater than 200
#x = t.statuses.user_timeline(screen_name="BernieSanders", count=20, include_rts=False, tweet_mode = 'extended')

# %%
# # Creating a for loop to inserts Hillary's tweets in a list
# Bernie_tweet = []
# for x in x:
#     Bernie_tweet.append(x)

# %%
# Bernie_tweet[0:5]

# %%
# type(Bernie_tweet)

# %%
# # I just want to focus on ids and tweets
# for element in Bernie_tweet:
#     print (element['id'])
#     print (element['full_text'])
#     print('---')

# %%
# #(TweetMiner) I found this function that easily organizes the tweets to input them into a panda dataframe

# class TweetMiner(object):

    
#     def __init__(self, t, result_limit = 200):
        
#         self.t = t        
#         self.result_limit = result_limit
        

#     def mine_user_tweets(self, user="BernieSanders", mine_retweets=False, max_pages=20):

#         data           =  []
#         last_tweet_id  =  False
#         page           =  1
        
#         while page <= max_pages:
            
#             if last_tweet_id:
#                 statuses   =   self.t.statuses.user_timeline(screen_name=user, count=self.result_limit, max_id=last_tweet_id - 1, include_rts=mine_retweets, tweet_mode = 'extended')
#                 statuses = [x for x in statuses]
#             else:
#                 statuses   =   self.t.statuses.user_timeline(screen_name=user, count=self.result_limit, include_rts=mine_retweets, tweet_mode = 'extended')
#                 statuses = [x for x in statuses]
                
#             for item in statuses:
#                 # Using try except here.
#                 # When retweets = 0 we get an error (GetUserTimeline fails to create a key, 'retweet_count')
#                 try:
#                     mined = {
#                         'tweet_id':        item['id'],
#                         'handle':          item['user']['screen_name'],
#                         'retweet_count':   item['retweet_count'],
#                         'text':            item['full_text'],
#                         'mined_at':        datetime.datetime.now(),
#                         'created_at':      item['created_at'],
#                     }
                
#                 except:
#                         mined = {
#                         'tweet_id':        item['id'],
#                         'handle':          item['user']['screen_name'],
#                         'retweet_count':   0,
#                         'text':            item['full_text'],
#                         'mined_at':        datetime.datetime.now(),
#                         'created_at':      item['created_at'],
#                     }
                
#                 last_tweet_id = item['id']
#                 data.append(mined)
                
#             page += 1
            
#         return data

# %%
# # Result limit == count parameter from our GetUserTimeline()
# miner = TweetMiner(t, result_limit=200)

# %%
# bernie = miner.mine_user_tweets(user="BernieSanders")
# elizabeth = miner.mine_user_tweets(user="ewarren")

# %%
# # each tweet is dictionary within a list
# bernie[0:5]

# %%
# for x in range(5):
#     print (bernie[x]['text'])
#     print('---')

# %%
# for x in range(5):
#     print (elizabeth[x]['text'])
#     print('--')

# %%
# # Turning Bernie's tweet into a dataframe:
# bernie_df = pd.DataFrame(bernie)
# bernie_df.head()

# %%
# # Doing the same for Elizabeth Warren
# miner = TweetMiner(t, result_limit=200)
# elizabeth_tweets = miner.mine_user_tweets("ewarren", max_pages=30)

# %%
# elizabeth_df = pd.DataFrame(elizabeth_tweets)

# %%
# elizabeth_df.head()

# %%
# bernie_df.shape

# %%
# elizabeth_df.shape

# %%
# # Joined elizabeth & Bernie Dataframe
# tweets = pd.concat([elizabeth_df, bernie_df], axis=0)
# tweets.shape

# %%
# tweets.head()

# %%
# The library below convert a collection of text documents to a matrix of token counts
from sklearn.feature_extraction.text import TfidfVectorizer

# The library stores dictionary values as counts 
from collections import Counter

# %%
# # Using TfidfVectorizer to find ngrams for Elizabeth's tweets
# vect = TfidfVectorizer(ngram_range=(2,5), stop_words='english')
# vect

# %%
# # Pulls all of Elizabeth's tweet text's into one giant string
# summaries = "".join(elizabeth_df['text'])
# summaries

# %%
# # vect.builder_analyzer handles the preprocessing, tokenization and n-grams generation
# ngrams_summaries = vect.build_analyzer()(summaries)
# ngrams_summaries

# %%
# Counter(ngrams_summaries).most_common(20)

# %%
# #Doing the same process for Bernie
# vect = TfidfVectorizer(ngram_range=(2,5), stop_words='english')

# summaries = "".join(bernie_df['text'])
# ngrams_summaries = vect.build_analyzer()(summaries)

# Counter(ngrams_summaries).most_common(20)

# %%
# #Wine search to look for #wine in the full text.  Twee_mode='extended' reflects the full tweet, not truncated.
# wine = t.search.tweets(q='$aapl', include_rts=False, tweet_mode='extended')

# %%
# type(wine)

# %%
# wine

# %%
# wine_list = wine['statuses']

# %%
# type(wine_list)

# %%
# wine_list

# %%
# # Showing how #wine reflects within the full text
# for element in wine_list[0:5]:
#     print (element['id'])
#     print (element['full_text'])
#     print('---')

# %%
# #(TweetMiner) I found this function that easily organizes the tweets to input them into a panda dataframe

# class TweetMiner(object):

    
#     def __init__(self, t, result_limit = 200):
        
#         self.t = t        
#         self.result_limit = result_limit
        

#     def mine_user_tweets(self, topic="#wine", mine_retweets=False, max_pages=20):

#         data           =  []
#         last_tweet_id  =  False
#         page           =  1
        
#         while page <= max_pages:
            
#             if last_tweet_id:
#                 statuses   =   self.t.search.tweets(q='#wine', count=self.result_limit, max_id=last_tweet_id - 1, include_rts=mine_retweets, tweet_mode='extended')
#                 statuses = [x for x in statuses['statuses']]
#             else:
#                 statuses   =   self.t.search.tweets(q='#wine', count=self.result_limit, include_rts=mine_retweets, tweet_mode='extended')
#                 statuses = [x for x in statuses['statuses']]
                
#             for item in statuses:
#                 # Using try except here.
#                 # When retweets = 0 we get an error (GetUserTimeline fails to create a key, 'retweet_count')
#                 try:
#                     mined = {
#                         'tweet_id':        item['id'],
#                         'handle':          item['user']['screen_name'],
#                         'retweet_count':   item['retweet_count'],
#                         'text':            item['full_text'],
#                         'mined_at':        datetime.datetime.now(),
#                         'created_at':      item['created_at'],
#                     }
                
#                 except:
#                         mined = {
#                         'tweet_id':        item['id'],
#                         'handle':          item['user']['screen_name'],
#                         'retweet_count':   0,
#                         'text':            item['full_text'],
#                         'mined_at':        datetime.datetime.now(),
#                         'created_at':      item['created_at'],
#                     }
                
#                 last_tweet_id = item['id']
#                 data.append(mined)
                
#             page += 1
            
#         return data

# %%
# miner = TweetMiner(t, result_limit=200)

# %%
# wine = miner.mine_user_tweets(topic="$appl")

# %%
# wine

# %%
# wine_tweet_df = pd.DataFrame(wine)
# wine_tweet_df.head()

# %%
# wine_list = (wine_tweet_df.text)

# %%
# type(wine_list)

# %%
# #Vectorizing the wine df
# vect = TfidfVectorizer(ngram_range=(2,5), stop_words='english')

# summaries = "".join(wine_tweet_df['text'])
# ngrams_summaries = vect.build_analyzer()(summaries)

# Counter(ngrams_summaries).most_common(20)

# %%
from textblob import TextBlob

# %%
# # Showing tweet sentiment in Bernie df
# # Polarity ranges from -1 (most negative) to 1 (most positive).
# # Subjectivity ranges from 0.0 (very objective) to 1.0 (very subjective)
# for tweet in bernie_df['text']:
#     print(tweet)
#     analysis = TextBlob(tweet)
#     print('---')
#     print(analysis.sentiment)
#     print('---')

# %%
# # Showing tweet sentiment in wine
# for tweet in wine_tweet_df['text']:
#     print(tweet)
#     analysis = TextBlob(tweet)
#     print(analysis.sentiment)
#     print('---')

# %%
# def detect_polarity(text):
#     return TextBlob(text).sentiment.polarity
#     wine_tweet_df['polarity'] = wine_tweet_df.text.apply(detect_polarity)
# wine_tweet_df.head(100)

# %%
ticker_df = pd.read_csv('constituents_csv.csv')

# %%
ticker_df.head()
# Out:
#    $-tag Symbol                 Name                  Sector
# 0   $MMM    MMM           3M Company             Industrials
# 1   $AOS    AOS      A.O. Smith Corp             Industrials
# 2   $ABT    ABT  Abbott Laboratories             Health Care
# 3  $ABBV   ABBV          AbbVie Inc.             Health Care
# 4   $ACN    ACN        Accenture plc  Information Technology

# %%
# wine_tweet_df.head()

# %%
# wine_tweet_df.shape

# %%
aapl_tweet= t.search.tweets(q='$aapl', include_rts=False, tweet_mode='extended', count=100)

# %%
type(aapl_tweet)
# Out:
# twitter.api.TwitterDictResponse

# %%
aapl_dict = aapl_tweet['statuses']

# %%
aapl_dict
# Out:
# [{'created_at': 'Thu Jan 09 23:33:24 +0000 2020',
#   'id': 1215416308969484288,
#   'id_str': '1215416308969484288',
#   'full_text': 'RT @charliebilello: The combined market cap of the 4 largest US companies is 13.8x higher than March 9, 2009. From $326 billion to $4.5 tri…',
#   'truncated': False,
#   'display_text_range': [0, 140],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'charliebilello',
#      'name': 'Charlie Bilello',
#      'id': 1413027896,
#      'id_str': '1413027896',
#      'indices': [3, 18]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 438614859,
#    'id_str': '438614859',
#    'name': '𝒫ℴ𝓅𓁹𝒞𝒽𝒶𝓇𝓉𝓈',
#    'screen_name': 'pop_ey_ch',
#    'location': '',
#    'description': 'I use chart patterns, EW principles to identify price extremes and reversals. Tweets/charts are not trade recommendations/advice.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 659,
#    'friends_count': 161,
#    'listed_count': 16,
#    'created_at': 'Fri Dec 16 20:14:05 +0000 2011',
#    'favourites_count': 1162,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 3657,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '5027D5',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1152689643416166405/Mjj0-SxU_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1152689643416166405/Mjj0-SxU_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/438614859/1563702437',
#    'profile_link_color': '3E1DA7',
#    'profile_sidebar_border_color': '12092F',
#    'profile_sidebar_fill_color': '1F0F51',
#    'profile_text_color': '301880',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Thu Jan 09 23:28:35 +0000 2020',
#    'id': 1215415100644958215,
#    'id_str': '1215415100644958215',
#    'full_text': 'The combined market cap of the 4 largest US companies is 13.8x higher than March 9, 2009. From $326 billion to $4.5 trillion. $AAPL $MSFT $GOOGL $AMZN https://t.co/XllM1xjBl0',
#    'truncated': False,
#    'display_text_range': [0, 150],
#    'entities': {'hashtags': [],
#     'symbols': [{'text': 'AAPL', 'indices': [126, 131]},
#      {'text': 'MSFT', 'indices': [132, 137]},
#      {'text': 'GOOGL', 'indices': [138, 144]},
#      {'text': 'AMZN', 'indices': [145, 150]}],
#     'user_mentions': [],
#     'urls': [],
#     'media': [{'id': 1215415097310371840,
#       'id_str': '1215415097310371840',
#       'indices': [151, 174],
#       'media_url': 'http://pbs.twimg.com/media/EN4Fl2nU4AAKFQK.png',
#       'media_url_https': 'https://pbs.twimg.com/media/EN4Fl2nU4AAKFQK.png',
#       'url': 'https://t.co/XllM1xjBl0',
#       'display_url': 'pic.twitter.com/XllM1xjBl0',
#       'expanded_url': 'https://twitter.com/charliebilello/status/1215415100644958215/photo/1',
#       'type': 'photo',
#       'sizes': {'small': {'w': 436, 'h': 198, 'resize': 'fit'},
#        'large': {'w': 436, 'h': 198, 'resize': 'fit'},
#        'medium': {'w': 436, 'h': 198, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}}}]},
#    'extended_entities': {'media': [{'id': 1215415097310371840,
#       'id_str': '1215415097310371840',
#       'indices': [151, 174],
#       'media_url': 'http://pbs.twimg.com/media/EN4Fl2nU4AAKFQK.png',
#       'media_url_https': 'https://pbs.twimg.com/media/EN4Fl2nU4AAKFQK.png',
#       'url': 'https://t.co/XllM1xjBl0',
#       'display_url': 'pic.twitter.com/XllM1xjBl0',
#       'expanded_url': 'https://twitter.com/charliebilello/status/1215415100644958215/photo/1',
#       'type': 'photo',
#       'sizes': {'small': {'w': 436, 'h': 198, 'resize': 'fit'},
#        'large': {'w': 436, 'h': 198, 'resize': 'fit'},
#        'medium': {'w': 436, 'h': 198, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}}}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1413027896,
#     'id_str': '1413027896',
#     'name': 'Charlie Bilello',
#     'screen_name': 'charliebilello',
#     'location': 'New York, NY',
#     'description': 'Founder and CEO of Compound Capital Advisors. Mission: guide investors on the road to a wealthy and meaningful life.',
#     'url': 'https://t.co/LU0bvzNGpd',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/LU0bvzNGpd',
#         'expanded_url': 'https://compoundadvisors.com/',
#         'display_url': 'compoundadvisors.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 135301,
#     'friends_count': 102,
#     'listed_count': 3288,
#     'created_at': 'Wed May 08 14:41:31 +0000 2013',
#     'favourites_count': 2418,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': True,
#     'statuses_count': 19118,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '050505',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1207655488168574976/N0sQdj76_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1207655488168574976/N0sQdj76_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1413027896/1576780572',
#     'profile_link_color': '061014',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 11,
#    'favorite_count': 23,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 11,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Jan 09 23:32:30 +0000 2020',
#   'id': 1215416084096000001,
#   'id_str': '1215416084096000001',
#   'full_text': 'RT @charliebilello: The combined market cap of the 4 largest US companies is 13.8x higher than March 9, 2009. From $326 billion to $4.5 tri…',
#   'truncated': False,
#   'display_text_range': [0, 140],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'charliebilello',
#      'name': 'Charlie Bilello',
#      'id': 1413027896,
#      'id_str': '1413027896',
#      'indices': [3, 18]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 2939272455,
#    'id_str': '2939272455',
#    'name': 'TheOriginalAqua[H20](Carlos)',
#    'screen_name': 'KingAquaV2',
#    'location': 'Born on the 3rd of a month ',
#    'description': "Carlos 'N' \n\n[A]qua Leader.  A Trustworthy OarFish.\nWater Algo now.\nMy commentary is my opinion and not advice.",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 85,
#    'friends_count': 197,
#    'listed_count': 2,
#    'created_at': 'Wed Dec 24 08:53:04 +0000 2014',
#    'favourites_count': 1325,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 10145,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1194755760271634437/mElbDthD_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1194755760271634437/mElbDthD_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2939272455/1575008220',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Thu Jan 09 23:28:35 +0000 2020',
#    'id': 1215415100644958215,
#    'id_str': '1215415100644958215',
#    'full_text': 'The combined market cap of the 4 largest US companies is 13.8x higher than March 9, 2009. From $326 billion to $4.5 trillion. $AAPL $MSFT $GOOGL $AMZN https://t.co/XllM1xjBl0',
#    'truncated': False,
#    'display_text_range': [0, 150],
#    'entities': {'hashtags': [],
#     'symbols': [{'text': 'AAPL', 'indices': [126, 131]},
#      {'text': 'MSFT', 'indices': [132, 137]},
#      {'text': 'GOOGL', 'indices': [138, 144]},
#      {'text': 'AMZN', 'indices': [145, 150]}],
#     'user_mentions': [],
#     'urls': [],
#     'media': [{'id': 1215415097310371840,
#       'id_str': '1215415097310371840',
#       'indices': [151, 174],
#       'media_url': 'http://pbs.twimg.com/media/EN4Fl2nU4AAKFQK.png',
#       'media_url_https': 'https://pbs.twimg.com/media/EN4Fl2nU4AAKFQK.png',
#       'url': 'https://t.co/XllM1xjBl0',
#       'display_url': 'pic.twitter.com/XllM1xjBl0',
#       'expanded_url': 'https://twitter.com/charliebilello/status/1215415100644958215/photo/1',
#       'type': 'photo',
#       'sizes': {'small': {'w': 436, 'h': 198, 'resize': 'fit'},
#        'large': {'w': 436, 'h': 198, 'resize': 'fit'},
#        'medium': {'w': 436, 'h': 198, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}}}]},
#    'extended_entities': {'media': [{'id': 1215415097310371840,
#       'id_str': '1215415097310371840',
#       'indices': [151, 174],
#       'media_url': 'http://pbs.twimg.com/media/EN4Fl2nU4AAKFQK.png',
#       'media_url_https': 'https://pbs.twimg.com/media/EN4Fl2nU4AAKFQK.png',
#       'url': 'https://t.co/XllM1xjBl0',
#       'display_url': 'pic.twitter.com/XllM1xjBl0',
#       'expanded_url': 'https://twitter.com/charliebilello/status/1215415100644958215/photo/1',
#       'type': 'photo',
#       'sizes': {'small': {'w': 436, 'h': 198, 'resize': 'fit'},
#        'large': {'w': 436, 'h': 198, 'resize': 'fit'},
#        'medium': {'w': 436, 'h': 198, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}}}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1413027896,
#     'id_str': '1413027896',
#     'name': 'Charlie Bilello',
#     'screen_name': 'charliebilello',
#     'location': 'New York, NY',
#     'description': 'Founder and CEO of Compound Capital Advisors. Mission: guide investors on the road to a wealthy and meaningful life.',
#     'url': 'https://t.co/LU0bvzNGpd',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/LU0bvzNGpd',
#         'expanded_url': 'https://compoundadvisors.com/',
#         'display_url': 'compoundadvisors.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 135301,
#     'friends_count': 102,
#     'listed_count': 3288,
#     'created_at': 'Wed May 08 14:41:31 +0000 2013',
#     'favourites_count': 2418,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': True,
#     'statuses_count': 19118,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '050505',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1207655488168574976/N0sQdj76_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1207655488168574976/N0sQdj76_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1413027896/1576780572',
#     'profile_link_color': '061014',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 11,
#    'favorite_count': 23,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 11,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Jan 09 23:32:21 +0000 2020',
#   'id': 1215416047261638657,
#   'id_str': '1215416047261638657',
#   'full_text': 'RT @charliebilello: The combined market cap of the 4 largest US companies is 13.8x higher than March 9, 2009. From $326 billion to $4.5 tri…',
#   'truncated': False,
#   'display_text_range': [0, 140],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'charliebilello',
#      'name': 'Charlie Bilello',
#      'id': 1413027896,
#      'id_str': '1413027896',
#      'indices': [3, 18]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 975781471087624192,
#    'id_str': '975781471087624192',
#    'name': 'I am lion',
#    'screen_name': 'sirmichko',
#    'location': 'World',
#    'description': "( Stocks - Crypto - Fx - Commodities ) signals, forecasts and news. Filtering out the noise. 'Markets bottom in Silence and Top with Violence.'",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 44,
#    'friends_count': 387,
#    'listed_count': 0,
#    'created_at': 'Mon Mar 19 17:10:06 +0000 2018',
#    'favourites_count': 3301,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 37737,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1202293615181148160/cs0C6uuu_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1202293615181148160/cs0C6uuu_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/975781471087624192/1572642407',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Thu Jan 09 23:28:35 +0000 2020',
#    'id': 1215415100644958215,
#    'id_str': '1215415100644958215',
#    'full_text': 'The combined market cap of the 4 largest US companies is 13.8x higher than March 9, 2009. From $326 billion to $4.5 trillion. $AAPL $MSFT $GOOGL $AMZN https://t.co/XllM1xjBl0',
#    'truncated': False,
#    'display_text_range': [0, 150],
#    'entities': {'hashtags': [],
#     'symbols': [{'text': 'AAPL', 'indices': [126, 131]},
#      {'text': 'MSFT', 'indices': [132, 137]},
#      {'text': 'GOOGL', 'indices': [138, 144]},
#      {'text': 'AMZN', 'indices': [145, 150]}],
#     'user_mentions': [],
#     'urls': [],
#     'media': [{'id': 1215415097310371840,
#       'id_str': '1215415097310371840',
#       'indices': [151, 174],
#       'media_url': 'http://pbs.twimg.com/media/EN4Fl2nU4AAKFQK.png',
#       'media_url_https': 'https://pbs.twimg.com/media/EN4Fl2nU4AAKFQK.png',
#       'url': 'https://t.co/XllM1xjBl0',
#       'display_url': 'pic.twitter.com/XllM1xjBl0',
#       'expanded_url': 'https://twitter.com/charliebilello/status/1215415100644958215/photo/1',
#       'type': 'photo',
#       'sizes': {'small': {'w': 436, 'h': 198, 'resize': 'fit'},
#        'large': {'w': 436, 'h': 198, 'resize': 'fit'},
#        'medium': {'w': 436, 'h': 198, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}}}]},
#    'extended_entities': {'media': [{'id': 1215415097310371840,
#       'id_str': '1215415097310371840',
#       'indices': [151, 174],
#       'media_url': 'http://pbs.twimg.com/media/EN4Fl2nU4AAKFQK.png',
#       'media_url_https': 'https://pbs.twimg.com/media/EN4Fl2nU4AAKFQK.png',
#       'url': 'https://t.co/XllM1xjBl0',
#       'display_url': 'pic.twitter.com/XllM1xjBl0',
#       'expanded_url': 'https://twitter.com/charliebilello/status/1215415100644958215/photo/1',
#       'type': 'photo',
#       'sizes': {'small': {'w': 436, 'h': 198, 'resize': 'fit'},
#        'large': {'w': 436, 'h': 198, 'resize': 'fit'},
#        'medium': {'w': 436, 'h': 198, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}}}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1413027896,
#     'id_str': '1413027896',
#     'name': 'Charlie Bilello',
#     'screen_name': 'charliebilello',
#     'location': 'New York, NY',
#     'description': 'Founder and CEO of Compound Capital Advisors. Mission: guide investors on the road to a wealthy and meaningful life.',
#     'url': 'https://t.co/LU0bvzNGpd',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/LU0bvzNGpd',
#         'expanded_url': 'https://compoundadvisors.com/',
#         'display_url': 'compoundadvisors.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 135301,
#     'friends_count': 102,
#     'listed_count': 3288,
#     'created_at': 'Wed May 08 14:41:31 +0000 2013',
#     'favourites_count': 2418,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': True,
#     'statuses_count': 19118,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '050505',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1207655488168574976/N0sQdj76_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1207655488168574976/N0sQdj76_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1413027896/1576780572',
#     'profile_link_color': '061014',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 11,
#    'favorite_count': 23,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 11,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Jan 09 23:31:55 +0000 2020',
#   'id': 1215415938146881538,
#   'id_str': '1215415938146881538',
#   'full_text': 'Nice closing candle today, $AAPL ripping',
#   'truncated': False,
#   'display_text_range': [0, 40],
#   'entities': {'hashtags': [],
#    'symbols': [{'text': 'AAPL', 'indices': [27, 32]}],
#    'user_mentions': [],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1204595527268151301,
#    'id_str': '1204595527268151301',
#    'name': 'Big Cap 🧢',
#    'screen_name': 'faang_gang',
#    'location': '',
#    'description': 'large cap investor - tracking market leaders and trends - with a side of personal finance #FAANGgang',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 27,
#    'friends_count': 53,
#    'listed_count': 0,
#    'created_at': 'Wed Dec 11 02:55:53 +0000 2019',
#    'favourites_count': 29,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 331,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1204612843288637445/irBf5ifI_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1204612843288637445/irBf5ifI_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1204595527268151301/1576035613',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Jan 09 23:31:42 +0000 2020',
#   'id': 1215415885021810690,
#   'id_str': '1215415885021810690',
#   'full_text': 'RT @charliebilello: The combined market cap of the 4 largest US companies is 13.8x higher than March 9, 2009. From $326 billion to $4.5 tri…',
#   'truncated': False,
#   'display_text_range': [0, 140],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'charliebilello',
#      'name': 'Charlie Bilello',
#      'id': 1413027896,
#      'id_str': '1413027896',
#      'indices': [3, 18]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 221861667,
#    'id_str': '221861667',
#    'name': 'Sami J. Karam 📈🌎🏛',
#    'screen_name': 'sami_karam',
#    'location': 'New York, NY',
#    'description': 'Analyst + Writer. Articles at Foreign Affairs, Natl Review, Quillette, New Geography, populyst. Son of an architect. My best tweets are at 5am. See you then.',
#    'url': 'https://t.co/a5ANnutfDB',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/a5ANnutfDB',
#        'expanded_url': 'http://populyst.net',
#        'display_url': 'populyst.net',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 406,
#    'friends_count': 279,
#    'listed_count': 21,
#    'created_at': 'Wed Dec 01 20:35:08 +0000 2010',
#    'favourites_count': 257,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 6363,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'FFFFFF',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1206732820581928960/jcDhhU73_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1206732820581928960/jcDhhU73_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/221861667/1577134895',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Thu Jan 09 23:28:35 +0000 2020',
#    'id': 1215415100644958215,
#    'id_str': '1215415100644958215',
#    'full_text': 'The combined market cap of the 4 largest US companies is 13.8x higher than March 9, 2009. From $326 billion to $4.5 trillion. $AAPL $MSFT $GOOGL $AMZN https://t.co/XllM1xjBl0',
#    'truncated': False,
#    'display_text_range': [0, 150],
#    'entities': {'hashtags': [],
#     'symbols': [{'text': 'AAPL', 'indices': [126, 131]},
#      {'text': 'MSFT', 'indices': [132, 137]},
#      {'text': 'GOOGL', 'indices': [138, 144]},
#      {'text': 'AMZN', 'indices': [145, 150]}],
#     'user_mentions': [],
#     'urls': [],
#     'media': [{'id': 1215415097310371840,
#       'id_str': '1215415097310371840',
#       'indices': [151, 174],
#       'media_url': 'http://pbs.twimg.com/media/EN4Fl2nU4AAKFQK.png',
#       'media_url_https': 'https://pbs.twimg.com/media/EN4Fl2nU4AAKFQK.png',
#       'url': 'https://t.co/XllM1xjBl0',
#       'display_url': 'pic.twitter.com/XllM1xjBl0',
#       'expanded_url': 'https://twitter.com/charliebilello/status/1215415100644958215/photo/1',
#       'type': 'photo',
#       'sizes': {'small': {'w': 436, 'h': 198, 'resize': 'fit'},
#        'large': {'w': 436, 'h': 198, 'resize': 'fit'},
#        'medium': {'w': 436, 'h': 198, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}}}]},
#    'extended_entities': {'media': [{'id': 1215415097310371840,
#       'id_str': '1215415097310371840',
#       'indices': [151, 174],
#       'media_url': 'http://pbs.twimg.com/media/EN4Fl2nU4AAKFQK.png',
#       'media_url_https': 'https://pbs.twimg.com/media/EN4Fl2nU4AAKFQK.png',
#       'url': 'https://t.co/XllM1xjBl0',
#       'display_url': 'pic.twitter.com/XllM1xjBl0',
#       'expanded_url': 'https://twitter.com/charliebilello/status/1215415100644958215/photo/1',
#       'type': 'photo',
#       'sizes': {'small': {'w': 436, 'h': 198, 'resize': 'fit'},
#        'large': {'w': 436, 'h': 198, 'resize': 'fit'},
#        'medium': {'w': 436, 'h': 198, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}}}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1413027896,
#     'id_str': '1413027896',
#     'name': 'Charlie Bilello',
#     'screen_name': 'charliebilello',
#     'location': 'New York, NY',
#     'description': 'Founder and CEO of Compound Capital Advisors. Mission: guide investors on the road to a wealthy and meaningful life.',
#     'url': 'https://t.co/LU0bvzNGpd',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/LU0bvzNGpd',
#         'expanded_url': 'https://compoundadvisors.com/',
#         'display_url': 'compoundadvisors.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 135301,
#     'friends_count': 102,
#     'listed_count': 3288,
#     'created_at': 'Wed May 08 14:41:31 +0000 2013',
#     'favourites_count': 2418,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': True,
#     'statuses_count': 19118,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '050505',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1207655488168574976/N0sQdj76_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1207655488168574976/N0sQdj76_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1413027896/1576780572',
#     'profile_link_color': '061014',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 11,
#    'favorite_count': 23,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 11,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Jan 09 23:30:54 +0000 2020',
#   'id': 1215415680482279424,
#   'id_str': '1215415680482279424',
#   'full_text': 'RT @stebottaioli: $AAPL $MSFT When the euphoria reaches the extreme phase https://t.co/6asapbMobV',
#   'truncated': False,
#   'display_text_range': [0, 97],
#   'entities': {'hashtags': [],
#    'symbols': [{'text': 'AAPL', 'indices': [18, 23]},
#     {'text': 'MSFT', 'indices': [24, 29]}],
#    'user_mentions': [{'screen_name': 'stebottaioli',
#      'name': 'Stefano Bottaioli',
#      'id': 4381519108,
#      'id_str': '4381519108',
#      'indices': [3, 16]}],
#    'urls': [],
#    'media': [{'id': 1215356069326786560,
#      'id_str': '1215356069326786560',
#      'indices': [74, 97],
#      'media_url': 'http://pbs.twimg.com/media/EN3P5-PWkAA4SfY.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/EN3P5-PWkAA4SfY.jpg',
#      'url': 'https://t.co/6asapbMobV',
#      'display_url': 'pic.twitter.com/6asapbMobV',
#      'expanded_url': 'https://twitter.com/stebottaioli/status/1215356083285434374/photo/1',
#      'type': 'photo',
#      'sizes': {'large': {'w': 819, 'h': 403, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 819, 'h': 403, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 335, 'resize': 'fit'}},
#      'source_status_id': 1215356083285434374,
#      'source_status_id_str': '1215356083285434374',
#      'source_user_id': 4381519108,
#      'source_user_id_str': '4381519108'}]},
#   'extended_entities': {'media': [{'id': 1215356069326786560,
#      'id_str': '1215356069326786560',
#      'indices': [74, 97],
#      'media_url': 'http://pbs.twimg.com/media/EN3P5-PWkAA4SfY.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/EN3P5-PWkAA4SfY.jpg',
#      'url': 'https://t.co/6asapbMobV',
#      'display_url': 'pic.twitter.com/6asapbMobV',
#      'expanded_url': 'https://twitter.com/stebottaioli/status/1215356083285434374/photo/1',
#      'type': 'photo',
#      'sizes': {'large': {'w': 819, 'h': 403, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 819, 'h': 403, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 335, 'resize': 'fit'}},
#      'source_status_id': 1215356083285434374,
#      'source_status_id_str': '1215356083285434374',
#      'source_user_id': 4381519108,
#      'source_user_id_str': '4381519108'}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 146590158,
#    'id_str': '146590158',
#    'name': 'Chartrambler',
#    'screen_name': 'Chartrambler',
#    'location': '',
#    'description': '',
#    'url': 'http://t.co/Sa8bMu4ddJ',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/Sa8bMu4ddJ',
#        'expanded_url': 'http://chartramblings.blogspot.com',
#        'display_url': 'chartramblings.blogspot.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 502,
#    'friends_count': 338,
#    'listed_count': 24,
#    'created_at': 'Fri May 21 20:55:21 +0000 2010',
#    'favourites_count': 18172,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 43606,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/2347222837/9n2p7b0il4x5f5wgmypj_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2347222837/9n2p7b0il4x5f5wgmypj_normal.jpeg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Thu Jan 09 19:34:05 +0000 2020',
#    'id': 1215356083285434374,
#    'id_str': '1215356083285434374',
#    'full_text': '$AAPL $MSFT When the euphoria reaches the extreme phase https://t.co/6asapbMobV',
#    'truncated': False,
#    'display_text_range': [0, 55],
#    'entities': {'hashtags': [],
#     'symbols': [{'text': 'AAPL', 'indices': [0, 5]},
#      {'text': 'MSFT', 'indices': [6, 11]}],
#     'user_mentions': [],
#     'urls': [],
#     'media': [{'id': 1215356069326786560,
#       'id_str': '1215356069326786560',
#       'indices': [56, 79],
#       'media_url': 'http://pbs.twimg.com/media/EN3P5-PWkAA4SfY.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EN3P5-PWkAA4SfY.jpg',
#       'url': 'https://t.co/6asapbMobV',
#       'display_url': 'pic.twitter.com/6asapbMobV',
#       'expanded_url': 'https://twitter.com/stebottaioli/status/1215356083285434374/photo/1',
#       'type': 'photo',
#       'sizes': {'large': {'w': 819, 'h': 403, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 819, 'h': 403, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 335, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1215356069326786560,
#       'id_str': '1215356069326786560',
#       'indices': [56, 79],
#       'media_url': 'http://pbs.twimg.com/media/EN3P5-PWkAA4SfY.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EN3P5-PWkAA4SfY.jpg',
#       'url': 'https://t.co/6asapbMobV',
#       'display_url': 'pic.twitter.com/6asapbMobV',
#       'expanded_url': 'https://twitter.com/stebottaioli/status/1215356083285434374/photo/1',
#       'type': 'photo',
#       'sizes': {'large': {'w': 819, 'h': 403, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 819, 'h': 403, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 335, 'resize': 'fit'}}}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 4381519108,
#     'id_str': '4381519108',
#     'name': 'Stefano Bottaioli',
#     'screen_name': 'stebottaioli',
#     'location': 'Cremona, Lombardia',
#     'description': 'Financial Advisor - Consulente finanziario - Private Banker - Analista',
#     'url': 'https://t.co/WKklxzKb4M',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/WKklxzKb4M',
#         'expanded_url': 'http://www.stefanobottaioli.it',
#         'display_url': 'stefanobottaioli.it',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 6074,
#     'friends_count': 240,
#     'listed_count': 138,
#     'created_at': 'Sat Dec 05 09:12:53 +0000 2015',
#     'favourites_count': 5803,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 8009,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/673068950809411584/LcXaZnid_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/673068950809411584/LcXaZnid_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4381519108/1449308725',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 4,
#    'favorite_count': 14,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 4,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Jan 09 23:30:46 +0000 2020',
#   'id': 1215415648458723329,
#   'id_str': '1215415648458723329',
#   'full_text': '@jimcramer @RedDogT3 saw this on @Twitter and would love to have commentary on thoughts.. do you think $AAPL goes to $530 by July 2020? https://t.co/yeW2iMAyO3',
#   'truncated': False,
#   'display_text_range': [0, 135],
#   'entities': {'hashtags': [],
#    'symbols': [{'text': 'AAPL', 'indices': [103, 108]}],
#    'user_mentions': [{'screen_name': 'jimcramer',
#      'name': 'Jim Cramer',
#      'id': 14216123,
#      'id_str': '14216123',
#      'indices': [0, 10]},
#     {'screen_name': 'RedDogT3',
#      'name': 'Scott Redler',
#      'id': 455824771,
#      'id_str': '455824771',
#      'indices': [11, 20]},
#     {'screen_name': 'Twitter',
#      'name': 'Twitter',
#      'id': 783214,
#      'id_str': '783214',
#      'indices': [33, 41]}],
#    'urls': [],
#    'media': [{'id': 1215415643698163712,
#      'id_str': '1215415643698163712',
#      'indices': [136, 159],
#      'media_url': 'http://pbs.twimg.com/media/EN4GFqEU8AA17gW.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/EN4GFqEU8AA17gW.jpg',
#      'url': 'https://t.co/yeW2iMAyO3',
#      'display_url': 'pic.twitter.com/yeW2iMAyO3',
#      'expanded_url': 'https://twitter.com/moneybythechart/status/1215415648458723329/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 680, 'h': 356, 'resize': 'fit'},
#       'large': {'w': 2048, 'h': 1072, 'resize': 'fit'},
#       'medium': {'w': 1200, 'h': 628, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 1215415643698163712,
#      'id_str': '1215415643698163712',
#      'indices': [136, 159],
#      'media_url': 'http://pbs.twimg.com/media/EN4GFqEU8AA17gW.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/EN4GFqEU8AA17gW.jpg',
#      'url': 'https://t.co/yeW2iMAyO3',
#      'display_url': 'pic.twitter.com/yeW2iMAyO3',
#      'expanded_url': 'https://twitter.com/moneybythechart/status/1215415648458723329/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 680, 'h': 356, 'resize': 'fit'},
#       'large': {'w': 2048, 'h': 1072, 'resize': 'fit'},
#       'medium': {'w': 1200, 'h': 628, 'resize': 'fit'}}}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': 14216123,
#   'in_reply_to_user_id_str': '14216123',
#   'in_reply_to_screen_name': 'jimcramer',
#   'user': {'id': 970028524072390656,
#    'id_str': '970028524072390656',
#    'name': 'Money By The Chart™️',
#    'screen_name': 'moneybythechart',
#    'location': '',
#    'description': 'Tweets are NOT Investing Advice, Just Commentary Through GIFS.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 112,
#    'friends_count': 178,
#    'listed_count': 0,
#    'created_at': 'Sat Mar 03 20:09:57 +0000 2018',
#    'favourites_count': 622,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 1324,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1169602908616159233/WDx709bm_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1169602908616159233/WDx709bm_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/970028524072390656/1567690055',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Jan 09 23:30:44 +0000 2020',
#   'id': 1215415637654286337,
#   'id_str': '1215415637654286337',
#   'full_text': '@RampCapitalLLC $AAPL',
#   'truncated': False,
#   'display_text_range': [16, 21],
#   'entities': {'hashtags': [],
#    'symbols': [{'text': 'AAPL', 'indices': [16, 21]}],
#    'user_mentions': [{'screen_name': 'RampCapitalLLC',
#      'name': 'Ramp Capital',
#      'id': 2214652482,
#      'id_str': '2214652482',
#      'indices': [0, 15]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'pl', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': 1215411713060720640,
#   'in_reply_to_status_id_str': '1215411713060720640',
#   'in_reply_to_user_id': 2214652482,
#   'in_reply_to_user_id_str': '2214652482',
#   'in_reply_to_screen_name': 'RampCapitalLLC',
#   'user': {'id': 190624745,
#    'id_str': '190624745',
#    'name': 'Stormn',
#    'screen_name': '5stormn',
#    'location': '3rd rock from the Sun ',
#    'description': "Twitter is a comedy app isn't it?\nSchool of hard knocks trained stock and options trader. For entertainment only. Invest for your own loss.",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 14,
#    'friends_count': 54,
#    'listed_count': 1,
#    'created_at': 'Tue Sep 14 12:45:55 +0000 2010',
#    'favourites_count': 192,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 635,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
# ...
#     {'text': 'BKR', 'indices': [72, 76]},
#     {'text': 'CL', 'indices': [77, 80]},
#     {'text': 'AMRN', 'indices': [81, 86]},
#     {'text': 'BBBY', 'indices': [87, 92]},
#     {'text': 'GM', 'indices': [93, 96]},
#     {'text': 'AMD', 'indices': [97, 101]},
#     {'text': 'GOLD', 'indices': [102, 107]},
#     {'text': 'GRPN', 'indices': [108, 113]},
#     {'text': 'SWK', 'indices': [114, 118]},
#     {'text': 'DNR', 'indices': [119, 123]},
#     {'text': 'OXY', 'indices': [124, 128]}],
#    'user_mentions': [],
#    'urls': [],
#    'media': [{'id': 1215403469848207360,
#      'id_str': '1215403469848207360',
#      'indices': [214, 237],
#      'media_url': 'http://pbs.twimg.com/media/EN37BC8UYAA2dgr.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/EN37BC8UYAA2dgr.jpg',
#      'url': 'https://t.co/qZEKxDmqrP',
#      'display_url': 'pic.twitter.com/qZEKxDmqrP',
#      'expanded_url': 'https://twitter.com/TeresaTrades/status/1215403472847175680/photo/1',
#      'type': 'photo',
#      'sizes': {'medium': {'w': 582, 'h': 853, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 464, 'h': 680, 'resize': 'fit'},
#       'large': {'w': 582, 'h': 853, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 1215403469848207360,
#      'id_str': '1215403469848207360',
#      'indices': [214, 237],
#      'media_url': 'http://pbs.twimg.com/media/EN37BC8UYAA2dgr.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/EN37BC8UYAA2dgr.jpg',
#      'url': 'https://t.co/qZEKxDmqrP',
#      'display_url': 'pic.twitter.com/qZEKxDmqrP',
#      'expanded_url': 'https://twitter.com/TeresaTrades/status/1215403472847175680/photo/1',
#      'type': 'photo',
#      'sizes': {'medium': {'w': 582, 'h': 853, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 464, 'h': 680, 'resize': 'fit'},
#       'large': {'w': 582, 'h': 853, 'resize': 'fit'}}}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 348544213,
#    'id_str': '348544213',
#    'name': 'TeresaTrades',
#    'screen_name': 'TeresaTrades',
#    'location': 'Alaska, USA',
#    'description': 'Options trader, seeker, & proud BlackBoxStocks member! #BuyAStoryNotATicker #ChickTradersRock *Email Teresa@BlackBoxStocks.com for free trial.',
#    'url': 'https://t.co/HxrGmFrUAl',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/HxrGmFrUAl',
#        'expanded_url': 'http://staygreen.blackboxstocks.com/SHt',
#        'display_url': 'staygreen.blackboxstocks.com/SHt',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 3229,
#    'friends_count': 787,
#    'listed_count': 73,
#    'created_at': 'Thu Aug 04 16:14:18 +0000 2011',
#    'favourites_count': 4756,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 14552,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/819758082024574976/Sf7RWUeN_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/819758082024574976/Sf7RWUeN_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/348544213/1484285749',
#    'profile_link_color': '19CF86',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 1,
#   'favorite_count': 1,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Jan 09 22:39:50 +0000 2020',
#   'id': 1215402831060054016,
#   'id_str': '1215402831060054016',
#   'full_text': 'Here is a tweet to take notice of...\n\n$AAPL https://t.co/ImTweQEIo9',
#   'truncated': False,
#   'display_text_range': [0, 43],
#   'entities': {'hashtags': [],
#    'symbols': [{'text': 'AAPL', 'indices': [38, 43]}],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/ImTweQEIo9',
#      'expanded_url': 'https://twitter.com/asymco/status/1215290802676461568',
#      'display_url': 'twitter.com/asymco/status/…',
#      'indices': [44, 67]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://tapbots.com/tweetbot" rel="nofollow">Tweetbot for iΟS</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 18903676,
#    'id_str': '18903676',
#    'name': 'Jonny',
#    'screen_name': 'Tilneys',
#    'location': '🇬🇧 & 🇮🇹  Next 🇬🇷 ',
#    'description': 'Mostly Apple \uf8ff and other 🤔',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 96,
#    'friends_count': 114,
#    'listed_count': 8,
#    'created_at': 'Mon Jan 12 15:37:07 +0000 2009',
#    'favourites_count': 2008,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 4690,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'B8B395',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme5/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme5/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/76694100/Picture_1_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/76694100/Picture_1_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/18903676/1574594948',
#    'profile_link_color': '3B94D9',
#    'profile_sidebar_border_color': 'DBE9ED',
#    'profile_sidebar_fill_color': 'E6F6F9',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': True,
#   'quoted_status_id': 1215290802676461568,
#   'quoted_status_id_str': '1215290802676461568',
#   'quoted_status': {'created_at': 'Thu Jan 09 15:14:41 +0000 2020',
#    'id': 1215290802676461568,
#    'id_str': '1215290802676461568',
#    'full_text': '@daveynb @DanielEran @rickvug @bullock_darcy RIM, Nokia, Sony, HP, RCA\nnot\nDisney, Facebook, Amazon, Microsoft \n\nBut which is Apple?\n\nThesis: it’s a more resilient brand than any of them.',
#    'truncated': False,
#    'display_text_range': [45, 187],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'daveynb',
#       'name': 'David Henderson',
#       'id': 256636336,
#       'id_str': '256636336',
#       'indices': [0, 8]},
#      {'screen_name': 'DanielEran',
#       'name': 'Daniel Eran Dilger',
#       'id': 15143065,
#       'id_str': '15143065',
#       'indices': [9, 20]},
#      {'screen_name': 'rickvug',
#       'name': 'Rick Vugteveen',
#       'id': 18040111,
#       'id_str': '18040111',
#       'indices': [21, 29]},
#      {'screen_name': 'bullock_darcy',
#       'name': 'Darcy Bullock',
#       'id': 2655918812,
#       'id_str': '2655918812',
#       'indices': [30, 44]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://tapbots.com/tweetbot" rel="nofollow">Tweetbot for iΟS</a>',
#    'in_reply_to_status_id': 1215288284047400960,
#    'in_reply_to_status_id_str': '1215288284047400960',
#    'in_reply_to_user_id': 256636336,
#    'in_reply_to_user_id_str': '256636336',
#    'in_reply_to_screen_name': 'daveynb',
#    'user': {'id': 110520327,
#     'id_str': '110520327',
#     'name': 'Horace Dediu',
#     'screen_name': 'asymco',
#     'location': '',
#     'description': 'A mind for the bicycle',
#     'url': 'https://t.co/cVy0bn7Irm',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/cVy0bn7Irm',
#         'expanded_url': 'http://www.asymco.com',
#         'display_url': 'asymco.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 65209,
#     'friends_count': 362,
#     'listed_count': 3632,
#     'created_at': 'Mon Feb 01 21:02:48 +0000 2010',
#     'favourites_count': 490,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 62998,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '1A1B1F',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/841929615765569536/zt2-1rg3_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/841929615765569536/zt2-1rg3_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/110520327/1519332325',
#     'profile_link_color': '2FC2EF',
#     'profile_sidebar_border_color': '181A1E',
#     'profile_sidebar_fill_color': '252429',
#     'profile_text_color': '666666',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Jan 09 22:34:00 +0000 2020',
#   'id': 1215401361606508544,
#   'id_str': '1215401361606508544',
#   'full_text': 'Some top money flow for Jan 9\n\nStart your free 7 day trial at https://t.co/8cfJGeucBk\n\n$TSLA $AAPL $AMD $GE $SPY $BA $LK\n#optionsflow #options #stocks https://t.co/tzTdSuMJdh',
#   'truncated': False,
#   'display_text_range': [0, 150],
#   'entities': {'hashtags': [{'text': 'optionsflow', 'indices': [121, 133]},
#     {'text': 'options', 'indices': [134, 142]},
#     {'text': 'stocks', 'indices': [143, 150]}],
#    'symbols': [{'text': 'TSLA', 'indices': [87, 92]},
#     {'text': 'AAPL', 'indices': [93, 98]},
#     {'text': 'AMD', 'indices': [99, 103]},
#     {'text': 'GE', 'indices': [104, 107]},
#     {'text': 'SPY', 'indices': [108, 112]},
#     {'text': 'BA', 'indices': [113, 116]},
#     {'text': 'LK', 'indices': [117, 120]}],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/8cfJGeucBk',
#      'expanded_url': 'http://cheddarflow.com',
#      'display_url': 'cheddarflow.com',
#      'indices': [62, 85]}],
#    'media': [{'id': 1215381500973051905,
#      'id_str': '1215381500973051905',
#      'indices': [151, 174],
#      'media_url': 'http://pbs.twimg.com/media/EN3nCSgUcAEsrv1.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/EN3nCSgUcAEsrv1.jpg',
#      'url': 'https://t.co/tzTdSuMJdh',
#      'display_url': 'pic.twitter.com/tzTdSuMJdh',
#      'expanded_url': 'https://twitter.com/CheddarFlow/status/1215401361606508544/photo/1',
#      'type': 'photo',
#      'sizes': {'large': {'w': 2048, 'h': 942, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 1200, 'h': 552, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 313, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 1215381500973051905,
#      'id_str': '1215381500973051905',
#      'indices': [151, 174],
#      'media_url': 'http://pbs.twimg.com/media/EN3nCSgUcAEsrv1.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/EN3nCSgUcAEsrv1.jpg',
#      'url': 'https://t.co/tzTdSuMJdh',
#      'display_url': 'pic.twitter.com/tzTdSuMJdh',
#      'expanded_url': 'https://twitter.com/CheddarFlow/status/1215401361606508544/photo/1',
#      'type': 'photo',
#      'sizes': {'large': {'w': 2048, 'h': 942, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 1200, 'h': 552, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 313, 'resize': 'fit'}}}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1004137473679679488,
#    'id_str': '1004137473679679488',
#    'name': 'Cheddar Flow',
#    'screen_name': 'CheddarFlow',
#    'location': 'San Francisco',
#    'description': "Track and monitor high quality option order flow in real time. It's time to follow the smart money. Learn more at https://t.co/S6mQ4iO7wM",
#    'url': 'https://t.co/UiFlP99JeQ',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/UiFlP99JeQ',
#        'expanded_url': 'http://www.cheddarflow.com',
#        'display_url': 'cheddarflow.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': [{'url': 'https://t.co/S6mQ4iO7wM',
#        'expanded_url': 'http://cheddarflow.com',
#        'display_url': 'cheddarflow.com',
#        'indices': [114, 137]}]}},
#    'protected': False,
#    'followers_count': 5770,
#    'friends_count': 158,
#    'listed_count': 181,
#    'created_at': 'Tue Jun 05 23:06:44 +0000 2018',
#    'favourites_count': 3625,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 12340,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1173955413856768000/33kmmO6f_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1173955413856768000/33kmmO6f_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1004137473679679488/1558400850',
#    'profile_link_color': '000000',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 1,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'}]

# %%
tw_list_date = []
tw_list_screen_name = []
tw_list_text = []
tw_list_retweet = []
tw_list_likes = []
tw_list_id = []
tw_list_polarity = []
for element in aapl_dict:
    tw_list_date.append(element['created_at'])
    tw_list_screen_name.append(element['user']['screen_name'])
    tw_list_text.append(element['full_text'])
    tw_list_retweet.append(element['retweet_count'])
    tw_list_likes.append(element['favorite_count'])
    tw_list_id.append(element['id'])
    analysis = TextBlob(element['full_text'])
    tw_list_polarity.append(analysis.sentiment.polarity)

# %%
tw_df = pd.DataFrame(list(zip(tw_list_date, tw_list_screen_name, tw_list_text, tw_list_retweet, tw_list_likes, tw_list_id, tw_list_polarity)), 
               columns =['created_date', 'handle', 'text', 'retweet_count', 'likes_count', 'tweet_id', 'polarity'])

# %%
sentiment_list = [] 
for value in tw_df["polarity"]: 
    if value == -1: 
        sentiment_list.append("Negative") 
    elif value > -1 and value < 0: 
        sentiment_list.append("Somewhat Negative")
    elif value == 0:
        sentiment_list.append('Neutral')
    elif value >= 0.1 and value <= 0.5:
        sentiment_list.append('Somewhat Postive')
    else: 
        sentiment_list.append("Positive")

# %%
tw_df['sentiment'] = sentiment_list

# %%
tw_df.head(50)
# Out:
#                       created_date           handle  \
# 0   Thu Jan 09 23:33:24 +0000 2020        pop_ey_ch
# 1   Thu Jan 09 23:32:30 +0000 2020       KingAquaV2
# 2   Thu Jan 09 23:32:21 +0000 2020        sirmichko
# 3   Thu Jan 09 23:31:55 +0000 2020       faang_gang
# 4   Thu Jan 09 23:31:42 +0000 2020       sami_karam
# 5   Thu Jan 09 23:30:54 +0000 2020     Chartrambler
# 6   Thu Jan 09 23:30:46 +0000 2020  moneybythechart
# 7   Thu Jan 09 23:30:44 +0000 2020          5stormn
# 8   Thu Jan 09 23:30:16 +0000 2020     TradeSmithTM
# 9   Thu Jan 09 23:30:12 +0000 2020          niremas
# 10  Thu Jan 09 23:30:10 +0000 2020  ExactOptionPick
# 11  Thu Jan 09 23:30:09 +0000 2020  Michael37230302
# 12  Thu Jan 09 23:30:00 +0000 2020    MichaelMOTTCM
# 13  Thu Jan 09 23:29:34 +0000 2020      reyricardor
# 14  Thu Jan 09 23:29:32 +0000 2020       archna2011
# 15  Thu Jan 09 23:29:30 +0000 2020         tommyabr
# 16  Thu Jan 09 23:29:26 +0000 2020    fundhunter_co
# 17  Thu Jan 09 23:29:08 +0000 2020        jlozada82
# 18  Thu Jan 09 23:29:02 +0000 2020        MCalixtoM
# 19  Thu Jan 09 23:28:54 +0000 2020      FinTwitAMZN
# 20  Thu Jan 09 23:28:35 +0000 2020   charliebilello
# 21  Thu Jan 09 23:27:19 +0000 2020       jerodjones
# 22  Thu Jan 09 23:26:04 +0000 2020      MacHashNews
# 23  Thu Jan 09 23:26:01 +0000 2020     stockspastor
# 24  Thu Jan 09 23:25:33 +0000 2020       MT__Bigsky
# 25  Thu Jan 09 23:25:31 +0000 2020    DogfatherMike
# 26  Thu Jan 09 23:25:00 +0000 2020   crushthemarket
# 27  Thu Jan 09 23:24:40 +0000 2020  BarrySchwartzBW
# 28  Thu Jan 09 23:23:35 +0000 2020  moneybythechart
# 29  Thu Jan 09 23:23:07 +0000 2020          jlay310
# 30  Thu Jan 09 23:20:26 +0000 2020     StatusTrader
# 31  Thu Jan 09 23:20:08 +0000 2020         delbar27
# 32  Thu Jan 09 23:18:19 +0000 2020     ErikFertsman
# 33  Thu Jan 09 23:18:18 +0000 2020    Samuel_Mobley
# 34  Thu Jan 09 23:18:10 +0000 2020  embrace_t_world
# 35  Thu Jan 09 23:18:00 +0000 2020   BullRunOptions
# 36  Thu Jan 09 23:17:36 +0000 2020    SultanBedaiwi
# 37  Thu Jan 09 23:17:22 +0000 2020         delbar27
# 38  Thu Jan 09 23:16:56 +0000 2020      Kris680NEWS
# 39  Thu Jan 09 23:16:46 +0000 2020       the_realRH
# 40  Thu Jan 09 23:16:37 +0000 2020  trueDennisNedry
# 41  Thu Jan 09 23:16:16 +0000 2020         delbar27
# 42  Thu Jan 09 23:14:55 +0000 2020     IBDinvestors
# 43  Thu Jan 09 23:13:15 +0000 2020    thecolour_red
# 44  Thu Jan 09 23:12:55 +0000 2020      IBD_ECarson
# 45  Thu Jan 09 23:12:54 +0000 2020        TEEELAZER
# 46  Thu Jan 09 23:12:37 +0000 2020   FocusedOptions
# 47  Thu Jan 09 23:12:34 +0000 2020  MC_OptionTrades
# 48  Thu Jan 09 23:11:18 +0000 2020      chiumeister
# 49  Thu Jan 09 23:10:01 +0000 2020          Watch4P
#
#                                                  text  retweet_count  \
# 0   RT @charliebilello: The combined market cap of...             11
# 1   RT @charliebilello: The combined market cap of...             11
# 2   RT @charliebilello: The combined market cap of...             11
# 3            Nice closing candle today, $AAPL ripping              0
# 4   RT @charliebilello: The combined market cap of...             11
# 5   RT @stebottaioli: $AAPL $MSFT When the euphori...              4
# 6   @jimcramer @RedDogT3 saw this on @Twitter and ...              0
# 7                               @RampCapitalLLC $AAPL              0
# 8   Did you see $AAPL was up in the #stockmarket? ...              0
# 9   RT @charliebilello: The combined market cap of...             11
# 10  ACTIVE TRADERS Try one of these FREE trading g...              0
# 11  Crazy day, extremely busy at work- missed PMPO...              0
# 12  #Stocks Continue To Climb Higher, But Is The #...              0
# 13  RT @charliebilello: The combined market cap of...             11
# 14  RT @charliebilello: The combined market cap of...             11
# 15  RT @charliebilello: The combined market cap of...             11
# 16  RT @charliebilello: The combined market cap of...             11
# 17  RT @Investingcom: 📈📈 Thursday Morning's #Top10...             10
# 18  RT @charliebilello: The combined market cap of...             11
# 19  via charliebilello: The combined market cap of...              0
# 20  The combined market cap of the 4 largest US co...             11
# 21  Apple iPhone sales in China score big jump htt...              0
# 22  Apple accused of stealing Masimo trade secrets...              0
# 23  RT @OptionsPastor: Enjoy the rest of your day ...              2
# 24  RT @crushthemarket: Charts Of The Day: Falling...              2
# 25  RT @crushthemarket: Charts Of The Day: Falling...              2
# 26  Charts Of The Day: Falling #earnings &amp; ris...              2
# 27  RT @FromValue: People who are saying that #Buf...              3
# 28                 $AAPL once again up in AH.. LOL!!!              0
# 29  how many notes is @WellsFargo $wfc issuing? #b...              0
# 30  $AAPL look at their debt, past earnings, and c...              0
# 31  RT @ManicTrading: TTN: $AAPL  Masimo sues Appl...              1
# 32  @wstpacglenn Agree. If you look at $aapl it lo...              0
# 33  $aapl\n\nFairly heavy volume on the 307.5x Jan...              0
# 34  $220 is the first hard resistance to $FB tomor...              0
# 35  Most Active Calls by size\n\n- $AAPL $40.06 M\...              0
# 36  RT @suhaildarraj: شركة ابل $AAPL أغلقت اليوم ب...              2
# 37  RT @newsfilterio: Apple Sued by Masimo Over Pa...              1
# 38  RT @680NEWS: Shares in #Apple continue to go w...              2
# 39                                              $AAPL              0
# 40  Only a moron would vote for bumbling baffoon s...              0
# 41       RT @MDLive4: $AAPL \nhttps://t.co/cSDvbygWFI              1
# 42  RT @IBD_ECarson: These 5 Top Stocks Are Surgin...              1
# 43  I have to start playing LEAPS, this is actuall...              0
# 44  These 5 Top Stocks Are Surging: Don't Buy Them...              1
# 45  $NOW\n2-3 green days https://t.co/exYNk2YUQF\n...              0
# 46                      $AAPL https://t.co/oWZyHRbG94              0
# 47  $AAPL 31-Jan-20 ATM Implied Volatility is up +...              0
# 48  My 2019 #MacPro arrived\nApple’s latest Mac De...              1
# 49  $aapl goes belly up tomorrow. Tsla has differe...              0
#
#     likes_count             tweet_id  polarity          sentiment
# 0             0  1215416308969484288  0.250000   Somewhat Postive
# 1             0  1215416084096000001  0.250000   Somewhat Postive
# 2             0  1215416047261638657  0.250000   Somewhat Postive
# 3             0  1215415938146881538  0.600000           Positive
# 4             0  1215415885021810690  0.250000   Somewhat Postive
# 5             0  1215415680482279424 -0.125000  Somewhat Negative
# 6             0  1215415648458723329  0.500000   Somewhat Postive
# 7             0  1215415637654286337  0.000000            Neutral
# 8             0  1215415522160009217  0.350000   Somewhat Postive
# 9             0  1215415506317873152  0.250000   Somewhat Postive
# 10            0  1215415497526738944  0.133333   Somewhat Postive
# 11            0  1215415491294105601 -0.144231  Somewhat Negative
# 12            1  1215415454077943808  0.375000   Somewhat Postive
# 13            0  1215415345395073025  0.250000   Somewhat Postive
# 14            0  1215415339816751106  0.250000   Somewhat Postive
# 15            0  1215415328836063242  0.250000   Somewhat Postive
# 16            0  1215415310804770821  0.250000   Somewhat Postive
# 17            0  1215415236615864320  0.500000   Somewhat Postive
# 18            0  1215415210523140101  0.250000   Somewhat Postive
# 19            0  1215415177270693888  0.250000   Somewhat Postive
# 20           23  1215415100644958215  0.250000   Somewhat Postive
# 21            0  1215414779159793664  0.000000            Neutral
# 22            0  1215414464935104512  0.000000            Neutral
# 23            0  1215414451979137029  0.400000   Somewhat Postive
# 24            0  1215414334467108864 -0.004545  Somewhat Negative
# 25            0  1215414326422458368 -0.004545  Somewhat Negative
# 26            3  1215414197040766976  0.046591           Positive
# 27            0  1215414113180012549  0.175000   Somewhat Postive
# 28            0  1215413841732857863  1.000000           Positive
# 29            0  1215413724351279104  0.150000   Somewhat Postive
# 30            0  1215413049336745984  0.225000   Somewhat Postive
# 31            0  1215412971435745281  0.000000            Neutral
# 32            0  1215412515942871040  0.563333           Positive
# 33            0  1215412509605158912  0.150000   Somewhat Postive
# 34            0  1215412475761291264  0.001667           Positive
# 35            0  1215412434393059328  0.183333   Somewhat Postive
# 36            0  1215412333247434757  0.000000            Neutral
# 37            0  1215412277215514624  0.000000            Neutral
# 38            0  1215412165559177216  0.500000   Somewhat Postive
# 39            0  1215412125017038848  0.000000            Neutral
# 40            0  1215412088111276032 -0.400000  Somewhat Negative
# 41            0  1215411999691005952  0.000000            Neutral
# 42            0  1215411659126210561  0.500000   Somewhat Postive
# 43            0  1215411237854633987 -0.333333  Somewhat Negative
# 44            3  1215411155604332546  0.500000   Somewhat Postive
# 45            0  1215411153871896577  0.087273           Positive
# 46            1  1215411081046364160  0.000000            Neutral
# 47            0  1215411069868482560  0.000000            Neutral
# 48            1  1215410749142634497  0.500000   Somewhat Postive
# 49            0  1215410426856509440 -0.133333  Somewhat Negative

# %%
tw_df.sentiment.unique()
# Out:
# array(['Somewhat Postive', 'Positive', 'Somewhat Negative', 'Neutral'],
#       dtype=object)

# %%
#Vectorizing the wine df
vect = TfidfVectorizer(ngram_range=(2,5), stop_words='english')

summaries = "".join(tw_df['text'])
ngrams_summaries = vect.build_analyzer()(summaries)

Counter(ngrams_summaries).most_common(20)
# Out:
# [('market cap', 14),
#  ('combined market', 12),
#  ('cap largest', 12),
#  ('largest companies', 12),
#  ('companies 13', 12),
#  ('13 8x', 12),
#  ('8x higher', 12),
#  ('higher march', 12),
#  ('march 2009', 12),
#  ('2009 326', 12),
#  ('326 billion', 12),
#  ('combined market cap', 12),
#  ('market cap largest', 12),
#  ('cap largest companies', 12),
#  ('largest companies 13', 12),
#  ('companies 13 8x', 12),
#  ('13 8x higher', 12),
#  ('8x higher march', 12),
#  ('higher march 2009', 12),
#  ('march 2009 326', 12)]
